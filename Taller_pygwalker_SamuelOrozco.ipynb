# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelorozco641/Seminario_Ciencia_Datos/blob/main/Taller_pygwalker_SamuelOrozco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygwalker
import pygwalker as pyg
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Seminario Ciencia Datos/dataset_banco.csv")
pyg.walk(data)

# %% [markdown]
# # **ACTIVIDAD 1 — Distribución de Variables**
#
# ![image.png](data:image/png;base64,...)
#
# *   **¿La variable tiene sesgo positivo o negativo?** R/La variable tiene un sesgo positivo, ya qye la mayoría de los valores son bajos y existen algunos valores muy altos que alargan el conteo a la derecha.
# *   **¿Se observan outliers?** R/ Se pueden observar outliers con varios valores extremos, especialmente con los saldos de algunos clientes los cuales son muy altos.
# *   **¿La variable parece adecuada para modelado o necesita transformación?** R/La variable podría necesitar una transformacion antes de ser usada en modelos, ya que tiene un fuerte sesgo y la presencia de outliers.

# %% [markdown]
# # **ACTIVIDAD 2 — Relación entre Variables Numéricas**
#
# ![image.png](data:image/png;base64,...)
#
#
#
# *   **¿La relación es fuerte o débil?** R/La realacion entre age y balance es debil, ya que los puntos aparecen muy dispersos y no se observa una concentración muy clara que indique una correlación fuerte.
# *   **¿Es lineal?** R/ No es lineal. A pesar de que la tendencia puede mostrar una inclinación positiva, la dispersión de los puntos indica que la relación no sigue una línea definida.
# *   **¿Esta relación podría ayudar a predecir otra variable?** R/ Debido a la baja correlación, no mucho. Seria mejor usar variables diferentes para mejorar la capacidad predictiva.

# %% [markdown]
# # **ACTIVIDAD 3 — Segmentación por Variable Categórica**
#
# ![image.png](data:image/png;base64,...)
#
# *   **¿Qué categoría tiene mayor promedio?** R/ La categoría de retired muestra los promedios más altos.
# *   **¿Dónde hay mayor variabilidad?** R/ La mayor variabilidad se observa en management y entrepreneur, ya que los valores del balance estan muy dispersos con algunos clientes teniendo un balance bajo y otros uno mas alto.
# *   **¿Algún grupo parece atípico?** R/ En varios grupos se pueden ver valores por fuera del boxplot. En las categorías de management, entrepreneur y retired se puede ver la gran mayoría.

# %% [markdown]
# # **ACTIVIDAD 4 — Análisis Multivariable**
#
# ![image.png](data:image/png;base64,...)
#
# *   **¿Se forman clusters?** R/ No se observan cluster definidos, ya que los puntos aparecen bastante dispersos y las diferentes categorías de trabajo se mezclan bastante entre si. A pesar de esto, se puede ver una concentración de puntos en balances bajos entre las edades de 25 a 50 años.
# *   **¿Algún grupo se separa claramente?** R/ Ningún grupo se separa completamente del resto, algunas categorías como retired tienden a aparecer en edades más altas, pero se sobreponen con otros grupos.
# *   **¿Qué variable parece más influyente?** R/ La variable que parece ser mas influyente es duration, ya que los puntos mas grandes del balance se asocian con respuestas especificas relacionadas a duration.

# %% [markdown]
# # **Entrega Final**
#
#
# A partir de los análisis que se realizaron mediante los diferentes gráficos, se identificaron algunos patrones relevantes en los datos de los clientes y sus características.
# La variable balance presenta una distribución con sesgo positivo en donde la mayoria de los clientes tienen saldos bajos o cercanos a cero, mientras que muy pocos presentan valores muy altos. Esto indica la presencia de outliers y una alta dispersión en los saldos de las cuentas. Ahora, al analizar la relación entre age y balance, se observa que no existe una relación clara ni fuerte, los puntos se encuentran bastante dispersos, lo que sugiere que la edad por sí sola no explica el comportamiento del saldo en la cuenta. Finalmente, al segmentar los datos por tipo de trabajo, se observan diferencias en la distribución de saldo entre las categorías, algunos grupos presentan saldos mas áltos en promedio, mientras que otros muestran valores más bajos, mencionando además que en varios grupos aparecen valores atípicos, lo que indica clientes con balances muy superiores al promedio.
#
# **Recomendaciones**
#
# Se recomienda en primer lugar el tratar con los valores atípicps de la variable balance antes de utilizarla en modelos de análisis o predicción, ya que asi se puede mejorar la estabilidad del modelo. En segundo lugar, se recomienda analizar la combinación de múltiples variables en lugar de depender de una sola variable para la predicción. Variables como job o duration pueden aportar una gran capacidad explicativa al modelo.
#
#
# Ahora, si buscaramos una variable objetivo, la variable más adecuada para esto sería "y", ya que esta indica si el cliente aceptó o no el producto ofrecido por el banco. Con ella se podrían crear modelos de clasificación que permitan predecir la probabilidad de que un cliente acepte una oferta.
#
#
# Las variables que podrían se predictoras son age, balance, job, marital, education, loan, duration, campaign o previous. Esto debido a que estas describen características demográficas, financieras y de interacción con el banco, por lo que pueden aportar información relevante para predecir el comportamiento del cliente.
